# %%
# !python3 train.py --img 640 --batch 32 --epochs 5 --adam \
--data PLVIS2D.yaml --weights yolov5n6.pt \
--hyp ./data/hyps/hyp.scratch.yaml
# Out:
# /bin/bash: switchml: line 1: syntax error: unexpected end of file
# /bin/bash: error importing function definition for `switchml'
# /bin/bash: _moduleraw: line 1: syntax error: unexpected end of file
# /bin/bash: error importing function definition for `_moduleraw'
# train: weights=yolov5n6.pt, cfg=, data=PLVIS2D.yaml, hyp=./data/hyps/hyp.scratch.yaml, epochs=5, batch_size=32, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, adam=True, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, linear_lr=False, label_smoothing=0.0, patience=100, freeze=0, save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: skipping check (not a git repository), for updates see https://github.com/ultralytics/yolov5
# ...

# %%
# !python3 train.py --img 640 --batch 32 --epochs 10 --adam \
--data PLVIS2D.yaml --weights ./runs/train/exp/weights/last.pt \
--hyp ./data/hyps/hyp.scratch.yaml
# Out:
# train: weights=./runs/train/exp/weights/last.pt, cfg=, data=PLVIS2D.yaml, hyp=./data/hyps/hyp.scratch.yaml, epochs=10, batch_size=32, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, adam=True, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, linear_lr=False, label_smoothing=0.0, patience=100, freeze=0, save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: skipping check (not a git repository), for updates see https://github.com/ultralytics/yolov5
# YOLOv5 🚀 2022-5-25 torch 1.8.1+cu111 CUDA:0 (Tesla T4, 15109.75MB)
#
# ...

# %%
# !python3 train.py --img 640 --batch 32 --epochs 100 --adam \
--data PLVIS2D.yaml --weights ./runs/train/exp5/weights/best.pt \
--hyp ./data/hyps/hyp-VISPL.scratch.yaml
# Out:
# train: weights=./runs/train/exp5/weights/best.pt, cfg=, data=PLVIS2D.yaml, hyp=./data/hyps/hyp-VISPL.scratch.yaml, epochs=100, batch_size=32, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, adam=True, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, linear_lr=False, label_smoothing=0.0, patience=100, freeze=0, save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: skipping check (not a git repository), for updates see https://github.com/ultralytics/yolov5
# YOLOv5 🚀 2022-5-25 torch 1.8.1+cu111 CUDA:0 (Tesla T4, 15109.75MB)
#
# ...

# %%
# !python3 train.py --img 640 --batch 32 --epochs 100 --adam \
--data PLVIS2D.yaml --weights ./runs/train/exp6/weights/best.pt \
--hyp ./data/hyps/hyp-VISPL.scratch.yaml
# Out:
# train: weights=./runs/train/exp6/weights/best.pt, cfg=, data=PLVIS2D.yaml, hyp=./data/hyps/hyp-VISPL.scratch.yaml, epochs=100, batch_size=32, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, adam=True, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, linear_lr=False, label_smoothing=0.0, patience=100, freeze=0, save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: skipping check (not a git repository), for updates see https://github.com/ultralytics/yolov5
# YOLOv5 🚀 2022-5-25 torch 1.8.1+cu111 CUDA:0 (Tesla T4, 15109.75MB)
#
# ...

# %%
# !python3 train.py --img 640 --batch 100 --epochs 100 --adam \
--data PLVIS2D.yaml --weights ./runs/train/exp7/weights/best.pt \
--hyp ./data/hyps/hyp-VISPL.scratch.yaml
# Out:
# train: weights=./runs/train/exp7/weights/best.pt, cfg=, data=PLVIS2D.yaml, hyp=./data/hyps/hyp-VISPL.scratch.yaml, epochs=100, batch_size=100, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, adam=True, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, linear_lr=False, label_smoothing=0.0, patience=100, freeze=0, save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: skipping check (not a git repository), for updates see https://github.com/ultralytics/yolov5
# YOLOv5 🚀 2022-5-25 torch 1.8.1+cu111 CUDA:0 (Tesla T4, 15109.75MB)
#
# ...

# %%
# !python3 train.py --img 640 --batch 32 --epochs 10 --adam \
--data PLVIS2D.yaml --weights ./runs/train/exp9/weights/best.pt \
--hyp ./data/hyps/hyp.scratch.yaml
# Out:
# train: weights=./runs/train/exp9/weights/best.pt, cfg=, data=PLVIS2D.yaml, hyp=./data/hyps/hyp.scratch.yaml, epochs=10, batch_size=32, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, adam=True, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, linear_lr=False, label_smoothing=0.0, patience=100, freeze=0, save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: skipping check (not a git repository), for updates see https://github.com/ultralytics/yolov5
# YOLOv5 🚀 2022-5-25 torch 1.8.1+cu111 CUDA:0 (Tesla T4, 15109.75MB)
#
# ...

# %%
# !python3 train.py --img 640 --batch 32 --epochs 10 --adam \
--data PLVIS2D.yaml --weights ./runs/train/exp9/weights/best.pt \
--hyp ./data/hyps/hyp.scratch.yaml --evolve
# Out:
# train: weights=./runs/train/exp9/weights/best.pt, cfg=, data=PLVIS2D.yaml, hyp=./data/hyps/hyp.scratch.yaml, epochs=10, batch_size=32, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, evolve=300, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, adam=True, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, linear_lr=False, label_smoothing=0.0, patience=100, freeze=0, save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: skipping check (not a git repository), for updates see https://github.com/ultralytics/yolov5
# YOLOv5 🚀 2022-5-25 torch 1.8.1+cu111 CUDA:0 (Tesla T4, 15109.75MB)
#
# ...

# %%
# !python3 train.py --img 640 --batch 32 --epochs 300 --adam \
--data PLVIS2D.yaml --weights ./runs/train/exp9/weights/best.pt \
--hyp ./runs/evolve/exp/hyp_evolve.yaml
# Out:
# train: weights=./runs/train/exp9/weights/best.pt, cfg=, data=PLVIS2D.yaml, hyp=./runs/evolve/exp/hyp_evolve.yaml, epochs=300, batch_size=32, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, adam=True, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, linear_lr=False, label_smoothing=0.0, patience=100, freeze=0, save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: skipping check (not a git repository), for updates see https://github.com/ultralytics/yolov5
# YOLOv5 🚀 2022-5-25 torch 1.8.1+cu111 CUDA:0 (Tesla T4, 15109.75MB)
#
# ...

# %%
# !python3 train.py --img 640 --batch 32 --epochs 300 --adam \
--data PLVIS2D.yaml --weights yolov5n6.pt \
--hyp ./runs/evolve/exp/hyp_evolve.yaml
# Out:
# train: weights=yolov5n6.pt, cfg=, data=PLVIS2D.yaml, hyp=./runs/evolve/exp/hyp_evolve.yaml, epochs=300, batch_size=32, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, adam=True, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, linear_lr=False, label_smoothing=0.0, patience=100, freeze=0, save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: skipping check (not a git repository), for updates see https://github.com/ultralytics/yolov5
# YOLOv5 🚀 2022-5-25 torch 1.8.1+cu111 CUDA:0 (Tesla T4, 15109.75MB)
#
# ...

# %%
# !python3 train.py --img 640 --batch 32 --epochs 300 --adam \
--data PLVIS2D.yaml --weights yolov5n6.pt \
--hyp ./runs/evolve/exp/hyp_evolve.yaml
# Out:
# /bin/bash: switchml: line 1: syntax error: unexpected end of file
# /bin/bash: error importing function definition for `switchml'
# /bin/bash: _moduleraw: line 1: syntax error: unexpected end of file
# /bin/bash: error importing function definition for `_moduleraw'
# train: weights=yolov5n6.pt, cfg=, data=PLVIS2D.yaml, hyp=./runs/evolve/exp/hyp_evolve.yaml, epochs=300, batch_size=32, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, adam=True, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, linear_lr=False, label_smoothing=0.0, patience=100, freeze=0, save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: skipping check (not a git repository), for updates see https://github.com/ultralytics/yolov5
# ...

# %%
# !python3 train.py --img 1280 --batch 32 --epochs 10 --adam \
--data PLVIS2D.yaml --weights ./runs/train/exp9/weights/best.pt \
--hyp ./data/hyps/hyp.scratch.yaml
# Out:
# train: weights=./runs/train/exp9/weights/best.pt, cfg=, data=PLVIS2D.yaml, hyp=./data/hyps/hyp.scratch.yaml, epochs=10, batch_size=32, imgsz=1280, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, adam=True, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, linear_lr=False, label_smoothing=0.0, patience=100, freeze=0, save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: skipping check (not a git repository), for updates see https://github.com/ultralytics/yolov5
# YOLOv5 🚀 2022-5-25 torch 1.8.1+cu111 CUDA:0 (Tesla T4, 15109.75MB)
#
# ...

# %% [markdown]
# # Validation

# %%
# !python3 val.py --img 640 --weights runs/train/exp9/weights/best.pt --data PLVIS2D.yaml
# Out:
# val: data=/home/ubuntu/bimodalyolov5/data/PLVIS2D.yaml, weights=['runs/train/exp9/weights/best.pt'], batch_size=32, imgsz=640, conf_thres=0.001, iou_thres=0.6, task=val, device=, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs/val, name=exp, exist_ok=False, half=False
# YOLOv5 🚀 2022-5-25 torch 1.8.1+cu111 CUDA:0 (Tesla T4, 15109.75MB)
#
# Fusing layers...
# Model Summary: 280 layers, 3089764 parameters, 0 gradients, 4.4 GFLOPs
# val: Scanning '../datasets/PLVIS2D/labels/val.cache' images and labels... 103 found, 0 missing, 0 empty, 0 corrupted
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        103        125      0.964      0.904      0.945      0.541
#                 Dirt        103         21      0.985          1      0.995      0.692
#                   ML        103        104      0.942      0.808      0.894      0.389
# ...

# %%
# !python3 val.py --img 640 --weights runs/train/exp13/weights/best.pt --data PLVIS2D.yaml
# Out:
# val: data=/home/ubuntu/bimodalyolov5/data/PLVIS2D.yaml, weights=['runs/train/exp13/weights/best.pt'], batch_size=32, imgsz=640, conf_thres=0.001, iou_thres=0.6, task=val, device=, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs/val, name=exp, exist_ok=False, half=False
# YOLOv5 🚀 2022-5-25 torch 1.8.1+cu111 CUDA:0 (Tesla T4, 15109.75MB)
#
# Fusing layers...
# Model Summary: 280 layers, 3089764 parameters, 0 gradients, 4.4 GFLOPs
# val: Scanning '../datasets/PLVIS2D/labels/val.cache' images and labels... 103 found, 0 missing, 0 empty, 0 corrupted
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        103        125      0.878      0.889      0.915      0.555
#                 Dirt        103         21      0.939          1      0.986      0.727
#                   ML        103        104      0.817      0.779      0.843      0.383
# ...

# %%
# !python3 val.py --img 640 --weights runs/train/exp14/weights/best.pt --data PLVIS2D.yaml
# Out:
# /bin/bash: switchml: line 1: syntax error: unexpected end of file
# /bin/bash: error importing function definition for `switchml'
# /bin/bash: _moduleraw: line 1: syntax error: unexpected end of file
# /bin/bash: error importing function definition for `_moduleraw'
# ...
# val: data=/home/ubuntu/bimodalyolov5/data/PLVIS2D.yaml, weights=['runs/train/exp14/weights/best.pt'], batch_size=32, imgsz=640, conf_thres=0.001, iou_thres=0.6, task=val, device=, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs/val, name=exp, exist_ok=False, half=False
# YOLOv5 🚀 2022-5-25 torch 1.8.1+cu111 CUDA:0 (Tesla T4, 15109.75MB)
#
# Fusing layers...
# Model Summary: 280 layers, 3089764 parameters, 0 gradients, 4.4 GFLOPs
# val: Scanning '../datasets/PLVIS2D/labels/val' images and labels...109 found, 0
# val: New cache created: ../datasets/PLVIS2D/labels/val.cache
# ...

# %%
# !python3 val.py --img 640 --weights runs/train/exp15/weights/best.pt --data PLVIS2D.yaml
# Out:
# /bin/bash: switchml: line 1: syntax error: unexpected end of file
# /bin/bash: error importing function definition for `switchml'
# /bin/bash: _moduleraw: line 1: syntax error: unexpected end of file
# /bin/bash: error importing function definition for `_moduleraw'
# val: data=/home/ubuntu/bimodalyolov5/data/PLVIS2D.yaml, weights=['runs/train/exp15/weights/best.pt'], batch_size=32, imgsz=640, conf_thres=0.001, iou_thres=0.6, task=val, device=, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs/val, name=exp, exist_ok=False, half=False
# YOLOv5 🚀 2022-5-25 torch 1.8.1+cu111 CUDA:0 (Tesla T4, 15109.75MB)
#
# Fusing layers...
# Model Summary: 280 layers, 3089764 parameters, 0 gradients, 4.4 GFLOPs
# val: Scanning '../datasets/PLVIS2D/labels/val.cache' images and labels... 109 found, 0 missing, 6 empty, 0 corrupted
#                Class     Images     Labels          P          R     mAP@.5 mAP@
# ...

# %% [markdown]
# # Test

# %%
# !python3 val.py --img 640 --weights runs/train/exp15/weights/best.pt --data PLVIS2D.yaml --task test
# Out:
# /bin/bash: switchml: line 1: syntax error: unexpected end of file
# /bin/bash: error importing function definition for `switchml'
# /bin/bash: _moduleraw: line 1: syntax error: unexpected end of file
# /bin/bash: error importing function definition for `_moduleraw'
# val: data=/home/ubuntu/bimodalyolov5/data/PLVIS2D.yaml, weights=['runs/train/exp15/weights/best.pt'], batch_size=32, imgsz=640, conf_thres=0.001, iou_thres=0.6, task=test, device=, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs/val, name=exp, exist_ok=False, half=False
# YOLOv5 🚀 2022-5-25 torch 1.8.1+cu111 CUDA:0 (Tesla T4, 15109.75MB)
#
# Fusing layers...
# Model Summary: 280 layers, 3089764 parameters, 0 gradients, 4.4 GFLOPs
# test: Scanning '../datasets/PLVIS2D/labels/test' images and labels...79 found, 0
# test: New cache created: ../datasets/PLVIS2D/labels/test.cache
# ...

# %%
# !python3 val.py --img 640 --weights runs/train/exp14/weights/best.pt --data PLVIS2D.yaml --task test
# Out:
# /bin/bash: switchml: line 1: syntax error: unexpected end of file
# /bin/bash: error importing function definition for `switchml'
# /bin/bash: _moduleraw: line 1: syntax error: unexpected end of file
# /bin/bash: error importing function definition for `_moduleraw'
# val: data=/home/ubuntu/bimodalyolov5/data/PLVIS2D.yaml, weights=['runs/train/exp14/weights/best.pt'], batch_size=32, imgsz=640, conf_thres=0.001, iou_thres=0.6, task=test, device=, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs/val, name=exp, exist_ok=False, half=False
# YOLOv5 🚀 2022-5-25 torch 1.8.1+cu111 CUDA:0 (Tesla T4, 15109.75MB)
#
# Fusing layers...
# Model Summary: 280 layers, 3089764 parameters, 0 gradients, 4.4 GFLOPs
# test: Scanning '../datasets/PLVIS2D/labels/test.cache' images and labels... 79 found, 0 missing, 7 empty, 0 corrupted
#                Class     Images     Labels          P          R     mAP@.5 mAP@
# ...

# %%
# !python3 val.py --img 640 --weights runs/train/exp13/weights/best.pt --data PLVIS2D.yaml --task test
# Out:
# /bin/bash: switchml: line 1: syntax error: unexpected end of file
# /bin/bash: error importing function definition for `switchml'
# /bin/bash: _moduleraw: line 1: syntax error: unexpected end of file
# /bin/bash: error importing function definition for `_moduleraw'
# val: data=/home/ubuntu/bimodalyolov5/data/PLVIS2D.yaml, weights=['runs/train/exp13/weights/best.pt'], batch_size=32, imgsz=640, conf_thres=0.001, iou_thres=0.6, task=test, device=, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs/val, name=exp, exist_ok=False, half=False
# YOLOv5 🚀 2022-5-25 torch 1.8.1+cu111 CUDA:0 (Tesla T4, 15109.75MB)
#
# Fusing layers...
# Model Summary: 280 layers, 3089764 parameters, 0 gradients, 4.4 GFLOPs
# test: Scanning '../datasets/PLVIS2D/labels/test.cache' images and labels... 79 found, 0 missing, 7 empty, 0 corrupted
#                Class     Images     Labels          P          R     mAP@.5 mAP@
# ...

# %%
# !python3 val.py --img 640 --weights runs/train/exp9/weights/best.pt --data PLVIS2D.yaml --task test
# Out:
# /bin/bash: switchml: line 1: syntax error: unexpected end of file
# /bin/bash: error importing function definition for `switchml'
# /bin/bash: _moduleraw: line 1: syntax error: unexpected end of file
# /bin/bash: error importing function definition for `_moduleraw'
# val: data=/home/ubuntu/bimodalyolov5/data/PLVIS2D.yaml, weights=['runs/train/exp9/weights/best.pt'], batch_size=32, imgsz=640, conf_thres=0.001, iou_thres=0.6, task=test, device=, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs/val, name=exp, exist_ok=False, half=False
# YOLOv5 🚀 2022-5-25 torch 1.8.1+cu111 CUDA:0 (Tesla T4, 15109.75MB)
#
# Fusing layers...
# Model Summary: 280 layers, 3089764 parameters, 0 gradients, 4.4 GFLOPs
# test: Scanning '../datasets/PLVIS2D/labels/test.cache' images and labels... 79 found, 0 missing, 7 empty, 0 corrupted
#                Class     Images     Labels          P          R     mAP@.5 mAP@
# ...

# %%
# !python3 val.py --img 640 --weights runs/train/exp15/weights/best.pt --data PLVIS2D.yaml --task train
# Out:
# /bin/bash: switchml: line 1: syntax error: unexpected end of file
# /bin/bash: error importing function definition for `switchml'
# /bin/bash: _moduleraw: line 1: syntax error: unexpected end of file
# /bin/bash: error importing function definition for `_moduleraw'
# val: data=/home/ubuntu/bimodalyolov5/data/PLVIS2D.yaml, weights=['runs/train/exp15/weights/best.pt'], batch_size=32, imgsz=640, conf_thres=0.001, iou_thres=0.6, task=train, device=, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs/val, name=exp, exist_ok=False, half=False
# YOLOv5 🚀 2022-5-25 torch 1.8.1+cu111 CUDA:0 (Tesla T4, 15109.75MB)
#
# Fusing layers...
# Model Summary: 280 layers, 3089764 parameters, 0 gradients, 4.4 GFLOPs
# train: Scanning '../datasets/PLVIS2D/labels/train.cache' images and labels... 996 found, 0 missing, 50 empty, 0 corrupted
#                Class     Images     Labels          P          R     mAP@.5 mAP@
# ...
