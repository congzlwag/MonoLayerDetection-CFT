# %%
# !python3 train.py --img 640 --batch 32 --epochs 20 --adam \
--data PLVIS2D_VISonly.yaml --weights yolov5n6.pt --name VISexp \
--hyp ./data/hyps/hyp.scratch.yaml
# Out:
# train: weights=yolov5n6.pt, cfg=, data=PLVIS2D_VISonly.yaml, hyp=./data/hyps/hyp.scratch.yaml, epochs=20, batch_size=32, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, adam=True, sync_bn=False, workers=8, project=runs/train, name=VISexp, exist_ok=False, quad=False, linear_lr=False, label_smoothing=0.0, patience=100, freeze=0, save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: skipping check (not a git repository), for updates see https://github.com/ultralytics/yolov5
# YOLOv5 🚀 2022-5-25 torch 1.8.1+cu111 CUDA:0 (Tesla T4, 15109.75MB)
#
# ...

# %%
# !python3 train.py --img 640 --batch 64 --epochs 10 --adam \
--data PLVIS2D_VISonly.yaml --weights ./runs/train/VISexp2/weights/best.pt --name VISexp \
--hyp ./data/hyps/hyp-VIS.scratch.yaml
# Out:
# train: weights=./runs/train/VISexp2/weights/best.pt, cfg=, data=PLVIS2D_VISonly.yaml, hyp=./data/hyps/hyp-VIS.scratch.yaml, epochs=10, batch_size=64, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, adam=True, sync_bn=False, workers=8, project=runs/train, name=VISexp, exist_ok=False, quad=False, linear_lr=False, label_smoothing=0.0, patience=100, freeze=0, save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: skipping check (not a git repository), for updates see https://github.com/ultralytics/yolov5
# YOLOv5 🚀 2022-5-25 torch 1.8.1+cu111 CUDA:0 (Tesla T4, 15109.75MB)
#
# ...

# %%
# !python3 train.py --img 640 --batch 64 --epochs 50 --adam \
--data PLVIS2D_VISonly.yaml --weights ./runs/train/VISexp4/weights/best.pt --name VISexp \
--hyp ./data/hyps/hyp-VIS.scratch.yaml
# Out:
# train: weights=./runs/train/VISexp4/weights/best.pt, cfg=, data=PLVIS2D_VISonly.yaml, hyp=./data/hyps/hyp-VIS.scratch.yaml, epochs=50, batch_size=64, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, adam=True, sync_bn=False, workers=8, project=runs/train, name=VISexp, exist_ok=False, quad=False, linear_lr=False, label_smoothing=0.0, patience=100, freeze=0, save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: skipping check (not a git repository), for updates see https://github.com/ultralytics/yolov5
# YOLOv5 🚀 2022-5-25 torch 1.8.1+cu111 CUDA:0 (Tesla T4, 15109.75MB)
#
# ...

# %%
# !python3 train.py --img 640 --batch 64 --epochs 100 --adam \
--data PLVIS2D_VISonly.yaml --weights ./runs/train/VISexp5/weights/best.pt --name VISexp \
--hyp ./data/hyps/hyp-VIS.scratch.yaml
# Out:
# train: weights=./runs/train/VISexp5/weights/best.pt, cfg=, data=PLVIS2D_VISonly.yaml, hyp=./data/hyps/hyp-VIS.scratch.yaml, epochs=100, batch_size=64, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, adam=True, sync_bn=False, workers=8, project=runs/train, name=VISexp, exist_ok=False, quad=False, linear_lr=False, label_smoothing=0.0, patience=100, freeze=0, save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: skipping check (not a git repository), for updates see https://github.com/ultralytics/yolov5
# YOLOv5 🚀 2022-5-25 torch 1.8.1+cu111 CUDA:0 (Tesla T4, 15109.75MB)
#
# ...

# %%
# !python3 train.py --img 640 --batch 64 --epochs 30 --adam \
--data PLVIS2D_VISonly.yaml --weights ./runs/train/VISexp6/weights/best.pt --name VISexp \
--hyp ./data/hyps/hyp.finetune.yaml
# Out:
# train: weights=./runs/train/VISexp6/weights/best.pt, cfg=, data=PLVIS2D_VISonly.yaml, hyp=./data/hyps/hyp.finetune.yaml, epochs=30, batch_size=64, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, adam=True, sync_bn=False, workers=8, project=runs/train, name=VISexp, exist_ok=False, quad=False, linear_lr=False, label_smoothing=0.0, patience=100, freeze=0, save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: skipping check (not a git repository), for updates see https://github.com/ultralytics/yolov5
# YOLOv5 🚀 2022-5-25 torch 1.8.1+cu111 CUDA:0 (Tesla T4, 15109.75MB)
#
# ...

# %%
# !python3 train.py --img 640 --batch 32 --epochs 50 --adam \
--data PLVIS2D_VISonly.yaml --weights yolov5n6.pt --name VISexp \
--hyp ./data/hyps/hyp.scratch.yaml --save-period 5
# Out:
# train: weights=yolov5n6.pt, cfg=, data=PLVIS2D_VISonly.yaml, hyp=./data/hyps/hyp.scratch.yaml, epochs=50, batch_size=32, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, adam=True, sync_bn=False, workers=8, project=runs/train, name=VISexp, exist_ok=False, quad=False, linear_lr=False, label_smoothing=0.0, patience=100, freeze=0, save_period=5, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: skipping check (not a git repository), for updates see https://github.com/ultralytics/yolov5
# YOLOv5 🚀 2022-5-25 torch 1.8.1+cu111 CUDA:0 (Tesla T4, 15109.75MB)
#
# ...

# %%
# !python3 train.py --img 640 --batch 64 --epochs 50 --adam \
--data PLVIS2D_VISonly.yaml --weights yolov5n6.pt --name VISexp \
--hyp ./data/hyps/hyp.scratch.yaml --save-period 5
# Out:
# train: weights=yolov5n6.pt, cfg=, data=PLVIS2D_VISonly.yaml, hyp=./data/hyps/hyp.scratch.yaml, epochs=50, batch_size=64, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, adam=True, sync_bn=False, workers=8, project=runs/train, name=VISexp, exist_ok=False, quad=False, linear_lr=False, label_smoothing=0.0, patience=100, freeze=0, save_period=5, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: skipping check (not a git repository), for updates see https://github.com/ultralytics/yolov5
# YOLOv5 🚀 2022-5-25 torch 1.8.1+cu111 CUDA:0 (Tesla T4, 15109.75MB)
#
# ...

# %% [markdown]
# # What if I don't load pretrained weights, just use the architecture?

# %%
# !python3 train.py --img 640 --batch 32 --epochs 10 --adam \
--data PLVIS2D_VISonly.yaml --cfg ./models/yolov5n.yaml --name VISexp \
--hyp ./data/hyps/hyp-VIS.scratch.yaml
# Out:
# train: weights=yolov5s.pt, cfg=./models/yolov5n.yaml, data=PLVIS2D_VISonly.yaml, hyp=./data/hyps/hyp-VIS.scratch.yaml, epochs=10, batch_size=32, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, adam=True, sync_bn=False, workers=8, project=runs/train, name=VISexp, exist_ok=False, quad=False, linear_lr=False, label_smoothing=0.0, patience=100, freeze=0, save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: skipping check (not a git repository), for updates see https://github.com/ultralytics/yolov5
# YOLOv5 🚀 2022-5-25 torch 1.8.1+cu111 CUDA:0 (Tesla T4, 15109.75MB)
#
# ...

# %% [markdown]
# ## OK following the suggestions from yolov5, train 300 epoches, with as large as possible batchsize

# %%
# !python3 train.py --img 640 --batch 128 --epochs 300 --adam \
--data PLVIS2D_VISonly.yaml --weights yolov5n6.pt --name VISexp \
--hyp ./data/hyps/hyp.scratch.yaml
# Out:
# train: weights=yolov5n6.pt, cfg=, data=PLVIS2D_VISonly.yaml, hyp=./data/hyps/hyp.scratch.yaml, epochs=300, batch_size=128, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, adam=True, sync_bn=False, workers=8, project=runs/train, name=VISexp, exist_ok=False, quad=False, linear_lr=False, label_smoothing=0.0, patience=100, freeze=0, save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: skipping check (not a git repository), for updates see https://github.com/ultralytics/yolov5
# YOLOv5 🚀 2022-5-25 torch 1.8.1+cu111 CUDA:0 (Tesla T4, 15109.75MB)
#
# ...

# %% [markdown]
# # Validation

# %%
# !python3 val.py --img 640 --weights runs/train/VISexp11/weights/best.pt \
--data PLVIS2D_VISonly.yaml --name VISexp
# Out:
# val: data=/home/ubuntu/bimodalyolov5/data/PLVIS2D_VISonly.yaml, weights=['runs/train/VISexp11/weights/best.pt'], batch_size=32, imgsz=640, conf_thres=0.001, iou_thres=0.6, task=val, device=, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs/val, name=VISexp, exist_ok=False, half=False
# YOLOv5 🚀 2022-5-25 torch 1.8.1+cu111 CUDA:0 (Tesla T4, 15109.75MB)
#
# Fusing layers...
# Model Summary: 280 layers, 3089188 parameters, 0 gradients, 4.2 GFLOPs
# val: Scanning '../datasets/PLVIS2D/labels/val.cache' images and labels... 109 found, 0 missing, 6 empty, 0 corrupted
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        109        125      0.543      0.606      0.557      0.212
#                 Dirt        109         21      0.875          1      0.985      0.395
#                   ML        109        104       0.21      0.212      0.129     0.0295
# ...

# %%
# !python3 val.py --img 640 --weights runs/train/VISexp11/weights/best.pt \
--data PLVIS2D_VISonly.yaml --name VISexp --task train
# Out:
# val: data=/home/ubuntu/bimodalyolov5/data/PLVIS2D_VISonly.yaml, weights=['runs/train/VISexp11/weights/best.pt'], batch_size=32, imgsz=640, conf_thres=0.001, iou_thres=0.6, task=train, device=, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs/val, name=VISexp, exist_ok=False, half=False
# YOLOv5 🚀 2022-5-25 torch 1.8.1+cu111 CUDA:0 (Tesla T4, 15109.75MB)
#
# Fusing layers...
# Model Summary: 280 layers, 3089188 parameters, 0 gradients, 4.2 GFLOPs
# train: Scanning '../datasets/PLVIS2D/labels/train.cache' images and labels... 996 found, 0 missing, 50 empty, 0 corrupted
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        996       1314      0.937      0.921      0.956      0.622
#                 Dirt        996        444       0.97      0.932      0.964      0.673
# ...

# %%
# !python3 val.py --img 640 --weights runs/train/VISexp7/weights/best.pt \
--data PLVIS2D_VISonly.yaml --name VISexp
# Out:
# val: data=/home/ubuntu/bimodalyolov5/data/PLVIS2D_VISonly.yaml, weights=['runs/train/VISexp7/weights/best.pt'], batch_size=32, imgsz=640, conf_thres=0.001, iou_thres=0.6, task=val, device=, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs/val, name=VISexp, exist_ok=False, half=False
# YOLOv5 🚀 2022-5-25 torch 1.8.1+cu111 CUDA:0 (Tesla T4, 15109.75MB)
#
# Fusing layers...
# Model Summary: 280 layers, 3089188 parameters, 0 gradients, 4.2 GFLOPs
# val: Scanning '../datasets/PLVIS2D/labels/val.cache' images and labels... 109 found, 0 missing, 6 empty, 0 corrupted
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        109        125      0.515      0.466      0.455      0.138
#                 Dirt        109         21      0.894      0.807      0.841       0.26
#                   ML        109        104      0.136      0.125      0.068     0.0152
# ...

# %%
# !python3 val.py --img 640 --weights runs/train/VISexp7/weights/best.pt \
--data PLVIS2D_VISonly.yaml --name VISexp --task train
# Out:
# val: data=/home/ubuntu/bimodalyolov5/data/PLVIS2D_VISonly.yaml, weights=['runs/train/VISexp7/weights/best.pt'], batch_size=32, imgsz=640, conf_thres=0.001, iou_thres=0.6, task=train, device=, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs/val, name=VISexp, exist_ok=False, half=False
# YOLOv5 🚀 2022-5-25 torch 1.8.1+cu111 CUDA:0 (Tesla T4, 15109.75MB)
#
# Fusing layers...
# Model Summary: 280 layers, 3089188 parameters, 0 gradients, 4.2 GFLOPs
# train: Scanning '../datasets/PLVIS2D/labels/train.cache' images and labels... 996 found, 0 missing, 50 empty, 0 corrupted
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        996       1314      0.823      0.767       0.82      0.449
#                 Dirt        996        444      0.872      0.797       0.86      0.519
# ...

# %%
# !python3 val.py --img 640 --weights runs/train/VISexp2/weights/best.pt \
--data PLVIS2D_VISonly.yaml --name VISexp
# Out:
# val: data=/home/ubuntu/bimodalyolov5/data/PLVIS2D_VISonly.yaml, weights=['runs/train/VISexp2/weights/best.pt'], batch_size=32, imgsz=640, conf_thres=0.001, iou_thres=0.6, task=val, device=, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs/val, name=VISexp, exist_ok=False, half=False
# YOLOv5 🚀 2022-5-25 torch 1.8.1+cu111 CUDA:0 (Tesla T4, 15109.75MB)
#
# Fusing layers...
# Model Summary: 280 layers, 3089188 parameters, 0 gradients, 4.2 GFLOPs
# val: Scanning '../datasets/PLVIS2D/labels/val.cache' images and labels... 109 found, 0 missing, 6 empty, 0 corrupted
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        109        125      0.216      0.249      0.196     0.0497
#                 Dirt        109         21      0.208      0.238      0.207     0.0519
#                   ML        109        104      0.224       0.26      0.185     0.0476
# ...

# %%
# !python3 val.py --img 640 --weights runs/train/VISexp2/weights/best.pt \
--data PLVIS2D_VISonly.yaml --name VISexp --task train
# Out:
# val: data=/home/ubuntu/bimodalyolov5/data/PLVIS2D_VISonly.yaml, weights=['runs/train/VISexp2/weights/best.pt'], batch_size=32, imgsz=640, conf_thres=0.001, iou_thres=0.6, task=train, device=, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs/val, name=VISexp, exist_ok=False, half=False
# YOLOv5 🚀 2022-5-25 torch 1.8.1+cu111 CUDA:0 (Tesla T4, 15109.75MB)
#
# Fusing layers...
# Model Summary: 280 layers, 3089188 parameters, 0 gradients, 4.2 GFLOPs
# train: Scanning '../datasets/PLVIS2D/labels/train.cache' images and labels... 996 found, 0 missing, 50 empty, 0 corrupted
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        996       1314      0.441      0.532      0.439       0.12
#                 Dirt        996        444      0.622      0.601      0.586      0.175
# ...

# %%
# !python3 val.py --img 640 --weights runs/train/VISexp14/weights/best.pt \
--data PLVIS2D_VISonly.yaml --name VISexp
# Out:
# val: data=/home/ubuntu/bimodalyolov5/data/PLVIS2D_VISonly.yaml, weights=['runs/train/VISexp14/weights/best.pt'], batch_size=32, imgsz=640, conf_thres=0.001, iou_thres=0.6, task=val, device=, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs/val, name=VISexp, exist_ok=False, half=False
# YOLOv5 🚀 2022-5-25 torch 1.8.1+cu111 CUDA:0 (Tesla T4, 15109.75MB)
#
# Fusing layers...
# Model Summary: 280 layers, 3089188 parameters, 0 gradients, 4.2 GFLOPs
# val: Scanning '../datasets/PLVIS2D/labels/val.cache' images and labels... 109 found, 0 missing, 6 empty, 0 corrupted
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        109        125      0.626      0.461       0.49      0.117
#                 Dirt        109         21      0.944      0.808      0.872      0.202
#                   ML        109        104      0.307      0.115      0.108     0.0327
# ...

# %%
# !python3 val.py --img 640 --weights runs/train/VISexp14/weights/epoch10.pt \
--data PLVIS2D_VISonly.yaml --name VISexp
# Out:
# YOLOv5 🚀 2022-5-25 torch 1.8.1+cu111 CUDA:0 (Tesla T4, 15109.75MB)
#
# Fusing layers...
# Model Summary: 280 layers, 3089188 parameters, 0 gradients, 4.2 GFLOPs
# val: Scanning '../datasets/PLVIS2D/labels/val.cache' images and labels... 109 found, 0 missing, 6 empty, 0 corrupted
#                Class     Images     Labels          P          R     mAP@.5 mAP@

# %%
# !python3 val.py --img 640 --weights runs/train/VISexp14/weights/best.pt \
--data PLVIS2D_VISonly.yaml --name VISexp --task train
# Out:
# val: data=/home/ubuntu/bimodalyolov5/data/PLVIS2D_VISonly.yaml, weights=['runs/train/VISexp14/weights/best.pt'], batch_size=32, imgsz=640, conf_thres=0.001, iou_thres=0.6, task=train, device=, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs/val, name=VISexp, exist_ok=False, half=False
# YOLOv5 🚀 2022-5-25 torch 1.8.1+cu111 CUDA:0 (Tesla T4, 15109.75MB)
#
# Fusing layers...
# Model Summary: 280 layers, 3089188 parameters, 0 gradients, 4.2 GFLOPs
# train: Scanning '../datasets/PLVIS2D/labels/train.cache' images and labels... 996 found, 0 missing, 50 empty, 0 corrupted
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        996       1314      0.941      0.911       0.95      0.582
#                 Dirt        996        444      0.978      0.923      0.959      0.581
# ...

# %%
# !python3 val.py --img 640 --weights runs/train/VISexp14/weights/best.pt \
--data PLVIS2D_VISonly.yaml --name VISexp --task test
# Out:
# val: data=/home/ubuntu/bimodalyolov5/data/PLVIS2D_VISonly.yaml, weights=['runs/train/VISexp14/weights/best.pt'], batch_size=32, imgsz=640, conf_thres=0.001, iou_thres=0.6, task=test, device=, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs/val, name=VISexp, exist_ok=False, half=False
# YOLOv5 🚀 2022-5-25 torch 1.8.1+cu111 CUDA:0 (Tesla T4, 15109.75MB)
#
# Fusing layers...
# Model Summary: 280 layers, 3089188 parameters, 0 gradients, 4.2 GFLOPs
# test: Scanning '../datasets/PLVIS2D/labels/test' images and labels...79 found, 0
# test: New cache created: ../datasets/PLVIS2D/labels/test.cache
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all         79         72        0.6       0.25      0.304        0.1
#                   ML         79         72        0.6       0.25      0.304        0.1
# ...
