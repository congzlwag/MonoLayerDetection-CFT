# %%
# !python3 train.py --img 640 --batch 32 --epochs 20 --data PLVIS2D_PLonly.yaml --weights yolov5n.pt
# Out:
# train: weights=yolov5n.pt, cfg=, data=PLVIS2D_PLonly.yaml, hyp=data/hyps/hyp.scratch.yaml, epochs=20, batch_size=32, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, adam=False, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, linear_lr=False, label_smoothing=0.0, patience=100, freeze=0, save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: skipping check (not a git repository), for updates see https://github.com/ultralytics/yolov5
# YOLOv5 🚀 2022-5-25 torch 1.8.1+cu111 CUDA:0 (Tesla T4, 15109.75MB)
#
# ...

# %%
# !python3 train.py --img 640 --batch 32 --epochs 20 --data PLVIS2D_PLonly.yaml --weights runs/train/exp/weights/best.pt --adam
# Out:
# train: weights=runs/train/exp/weights/best.pt, cfg=, data=PLVIS2D_PLonly.yaml, hyp=data/hyps/hyp.scratch.yaml, epochs=20, batch_size=32, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, adam=True, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, linear_lr=False, label_smoothing=0.0, patience=100, freeze=0, save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: skipping check (not a git repository), for updates see https://github.com/ultralytics/yolov5
# YOLOv5 🚀 2022-5-25 torch 1.8.1+cu111 CUDA:0 (Tesla T4, 15109.75MB)
#
# ...

# %%
# !python3 train.py --img 640 --batch 32 --epochs 200 --data PLVIS2D_PLonly.yaml --weights runs/train/exp2/weights/best.pt --adam
# Out:
# train: weights=runs/train/exp2/weights/best.pt, cfg=, data=PLVIS2D_PLonly.yaml, hyp=data/hyps/hyp.scratch.yaml, epochs=200, batch_size=32, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, adam=True, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, linear_lr=False, label_smoothing=0.0, patience=100, freeze=0, save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: skipping check (not a git repository), for updates see https://github.com/ultralytics/yolov5
# YOLOv5 🚀 2022-5-25 torch 1.8.1+cu111 CUDA:0 (Tesla T4, 15109.75MB)
#
# ...

# %%
# !python3 val.py --img 640 --weights runs/train/exp3/weights/best.pt --data PLVIS2D_PLonly.yaml
# Out:
# val: data=/home/ubuntu/bimodalyolov5/data/PLVIS2D_PLonly.yaml, weights=['runs/train/exp3/weights/best.pt'], batch_size=32, imgsz=640, conf_thres=0.001, iou_thres=0.6, task=val, device=, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs/val, name=exp, exist_ok=False, half=False
# YOLOv5 🚀 2022-5-25 torch 1.8.1+cu111 CUDA:0 (Tesla T4, 15109.75MB)
#
# Fusing layers...
# Model Summary: 213 layers, 1761871 parameters, 0 gradients, 4.2 GFLOPs
# val: Scanning '../datasets/PLVIS2D/labels/PL.cache' images and labels... 13 foun
# val: Scanning '../datasets/PLVIS2D/labels/PL.cache' images and labels... 13 foun
# val: Scanning '../datasets/PLVIS2D/labels/PL.cache' images and labels... 13 foun
#                Class     Images     Labels          P          R     mAP@.5 mAP@
# val: Scanning '../datasets/PLVIS2D/labels/PL.cache' images and labels... 13 foun
# ...

# %%
# !python3 train.py --img 640 --batch 32 --epochs 1 --data PLVIS2D_PLonly.yaml --weights yolov5n6.pt
# Out:
# train: weights=yolov5n6.pt, cfg=, data=PLVIS2D_PLonly.yaml, hyp=data/hyps/hyp.scratch.yaml, epochs=1, batch_size=32, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, adam=False, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, linear_lr=False, label_smoothing=0.0, patience=100, freeze=0, save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: skipping check (not a git repository), for updates see https://github.com/ultralytics/yolov5
# YOLOv5 🚀 2022-5-25 torch 1.8.1+cu111 CUDA:0 (Tesla T4, 15109.75MB)
#
# ...

# %%
# !python3 train.py --img 640 --batch 32 --epochs 1 --data PLVIS2D.yaml --weights yolov5n6.pt
# Out:
# train: weights=yolov5n6.pt, cfg=, data=PLVIS2D.yaml, hyp=data/hyps/hyp.scratch.yaml, epochs=1, batch_size=32, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, adam=False, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, linear_lr=False, label_smoothing=0.0, patience=100, freeze=0, save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: skipping check (not a git repository), for updates see https://github.com/ultralytics/yolov5
# YOLOv5 🚀 2022-5-25 torch 1.8.1+cu111 CUDA:0 (Tesla T4, 15109.75MB)
#
# ...

# %%
from skimage import transform, io
imgPL = io.imread("../datasets/PLVIS2D/images/train/PL/009.jpg")
imgWL = io.imread("../datasets/PLVIS2D/images/train/WL/009.jpg")

# %%
img = (0.5*imgWL + 0.5*imgPL[:,:,None])

# %%
io.imshow(imgPL)

# %%
imgPL.dtype
# Out:
# dtype('uint8')

# %%
io.imshow(img.astype(np.uint8))

# %%
import cv2

# %%
img_rgb = cv2.cvtColor(img,cv2.COLOR_GRAY2RGB)

# %%
img_rgb
# Out:
# array([[[ 9,  9,  9],
#         [ 9,  9,  9],
#         [ 9,  9,  9],
#         ...,
#         [10, 10, 10],
#         [10, 10, 10],
#         [10, 10, 10]],
#
#        [[11, 11, 11],
#         [11, 11, 11],
#         [11, 11, 11],
#         ...,
#         [10, 10, 10],
#         [10, 10, 10],
#         [10, 10, 10]],
#
#        [[ 8,  8,  8],
#         [ 8,  8,  8],
#         [ 8,  8,  8],
#         ...,
#         [10, 10, 10],
#         [10, 10, 10],
#         [10, 10, 10]],
#
#        ...,
#
#        [[10, 10, 10],
#         [10, 10, 10],
#         [10, 10, 10],
#         ...,
#         [20, 20, 20],
#         [16, 16, 16],
#         [ 6,  6,  6]],
#
#        [[10, 10, 10],
#         [10, 10, 10],
#         [10, 10, 10],
#         ...,
#         [25, 25, 25],
#         [22, 22, 22],
#         [12, 12, 12]],
#
#        [[10, 10, 10],
#         [10, 10, 10],
#         [10, 10, 10],
#         ...,
#         [18, 18, 18],
#         [15, 15, 15],
#         [ 5,  5,  5]]], dtype=uint8)

# %%
io.imshow(img)

# %%
from PIL import Image
import os

# %%
dum = {1:"a"}

# %%
dum.get(2,'b')
# Out:
# 'b'

# %%
cache_path = "../datasets/PLVIS2D/labels/train.cache"
cache = np.load(cache_path, allow_pickle=True)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-81-ea1eae4156e5> in <module>
#       1 cache_path = "../datasets/PLVIS2D/labels/train.cache"
# ----> 2 cache = np.load(cache_path, allow_pickle=True)
#
# ~/anaconda3/envs/pytorch_latest_p37/lib/python3.7/site-packages/numpy/lib/npyio.py in load(file, mmap_mode, allow_pickle, fix_imports, encoding)
#     414             own_fid = False
#     415         else:
# --> 416             fid = stack.enter_context(open(os_fspath(file), "rb"))
#     417             own_fid = True
#     418
#
# FileNotFoundError: [Errno 2] No such file or directory: '../datasets/PLVIS2D/labels/train.cache'

# %%
os.path.splitext("../datasets/PLVIS2D/images/train/Union/002.npy")[1]
# Out:
# '.npy'

# %%
Image.open("../datasets/PLVIS2D/images/train/Union/002.npy")
# Out:
# ---------------------------------------------------------------------------
# UnidentifiedImageError                    Traceback (most recent call last)
# <ipython-input-54-3ab5afde1aea> in <module>
# ----> 1 Image.open("../datasets/PLVIS2D/images/train/Union/002.npy")
#
# ~/anaconda3/envs/pytorch_latest_p37/lib/python3.7/site-packages/PIL/Image.py in open(fp, mode, formats)
#    3022         warnings.warn(message)
#    3023     raise UnidentifiedImageError(
# -> 3024         "cannot identify image file %r" % (filename if filename else fp)
#    3025     )
#    3026
#
# UnidentifiedImageError: cannot identify image file '../datasets/PLVIS2D/images/train/Union/002.npy'

# %%
from utils.general import colorstr

# %%
ct = colorstr("train: ")

# %%
ct
# Out:
# '\x1b\x1btrain: \x1b'

# %%
import cv2
import numpy as np

# %%
fnam0 = "../datasets/PLVIS2D/images/train/PL/002.jpg"
im0_uc = cv2.imread(fnam0,cv2.IMREAD_UNCHANGED)
im0    = cv2.imread(fnam0)

# %%
np.repeat(im0_uc,

# %%
np.all(np.tile(im0_uc,(3,1,1)).transpose((1,2,0))[:,:,0] == im0_uc)
# Out:
# True

# %%
print(im0.shape)
print(np.allclose(im0_uc, im0))
# Out:
# (1200, 1920, 3)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-fc7c5d623f1e> in <module>
#       1 print(im0.shape)
# ----> 2 print(np.allclose(im0_uc, im0))
#
# <__array_function__ internals> in allclose(*args, **kwargs)
#
# ~/anaconda3/envs/pytorch_latest_p37/lib/python3.7/site-packages/numpy/core/numeric.py in allclose(a, b, rtol, atol, equal_nan)
#    2187
#    2188     """
# -> 2189     res = all(isclose(a, b, rtol=rtol, atol=atol, equal_nan=equal_nan))
#    2190     return bool(res)
#    2191
#
# <__array_function__ internals> in isclose(*args, **kwargs)
#
# ~/anaconda3/envs/pytorch_latest_p37/lib/python3.7/site-packages/numpy/core/numeric.py in isclose(a, b, rtol, atol, equal_nan)
#    2288     yfin = isfinite(y)
#    2289     if all(xfin) and all(yfin):
# -> 2290         return within_tol(x, y, atol, rtol)
#    2291     else:
# ...
